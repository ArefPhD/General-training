# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/timsainb/tensorflow2-generative-models/blob/master/2.0-GAN-fashion-mnist.ipynb)
#
# ## Generative Adversarial Network (GAN)
# GANs are a form of neural network in which two sub-networks (the encoder and decoder) are trained on opposing loss functions: an encoder that is trained to produce data which is indiscernable from the true data, and a decoder that is trained to discern between the data and generated data.
#
# ![gan](https://github.com/timsainb/tensorflow2-generative-models/blob/master/imgs/gan.png?raw=1)

# %% [markdown]
# ### Install packages if in colab

# %%
### install necessary packages if in colab
def run_subprocess_command(cmd):
    process = subprocess.Popen(cmd.split(), stdout=subprocess.PIPE)
    for line in process.stdout:
        print(line.decode().strip())


import sys, subprocess

IN_COLAB = "google.colab" in sys.modules
colab_requirements = ["pip install tf-nightly-gpu-2.0-preview==2.0.0.dev20190513"]
if IN_COLAB:
    for i in colab_requirements:
        run_subprocess_command(i)

# %% [markdown]
# ### load packages

# %%
import tensorflow as tf

# %%
tf.compat.v1.enable_eager_execution()

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tqdm.autonotebook import tqdm
# %matplotlib inline
from IPython import display
import pandas as pd

# %%
print(tf.__version__)
# Out:
# 2.5.0

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %% [markdown]
# ### Create a fashion-MNIST dataset

# %%
TRAIN_BUF=300
BATCH_SIZE=10
TEST_BUF=100
DIMS = (28,28,1)
N_TRAIN_BATCHES =int(TRAIN_BUF/BATCH_SIZE)
N_TEST_BATCHES = int(TEST_BUF/BATCH_SIZE)

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-8a393a04-5f82-40a6-b567-88c6009aa9d5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8a393a04-5f82-40a6-b567-88c6009aa9d5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 0.jpg to 0 (1).jpg
# Saving 1.jpg to 1 (1).jpg
# Saving 2.jpg to 2 (1).jpg
# Saving 3.jpg to 3 (1).jpg
# Saving 4.jpg to 4 (1).jpg
# Saving 5.jpg to 5 (1).jpg
# Saving 6.jpg to 6 (1).jpg
# Saving 7.jpg to 7 (1).jpg
# Saving 8.jpg to 8 (1).jpg
# Saving 9.jpg to 9 (1).jpg
# Saving 10.jpg to 10 (1).jpg
# Saving 11.jpg to 11 (1).jpg
# Saving 12.jpg to 12 (1).jpg
# Saving 13.jpg to 13 (1).jpg
# Saving 14.jpg to 14 (1).jpg
# Saving 15.jpg to 15 (1).jpg
# Saving 16.jpg to 16 (1).jpg
# Saving 17.jpg to 17 (1).jpg
# Saving 18.jpg to 18 (1).jpg
# Saving 19.jpg to 19 (1).jpg
# Saving 20.jpg to 20 (1).jpg
# Saving 21.jpg to 21 (1).jpg
# Saving 22.jpg to 22 (1).jpg
# Saving 23.jpg to 23 (1).jpg
# Saving 24.jpg to 24 (1).jpg
# Saving 25.jpg to 25 (1).jpg
# Saving 26.jpg to 26 (1).jpg
# Saving 27.jpg to 27 (1).jpg
# Saving 28.jpg to 28 (1).jpg
# Saving 29.jpg to 29 (1).jpg
# Saving 30.jpg to 30 (1).jpg
# Saving 31.jpg to 31 (1).jpg
# Saving 32.jpg to 32 (1).jpg
# Saving 33.jpg to 33 (1).jpg
# Saving 34.jpg to 34 (1).jpg
# Saving 35.jpg to 35 (1).jpg
# Saving 36.jpg to 36 (1).jpg
# Saving 37.jpg to 37 (1).jpg
# Saving 38.jpg to 38 (1).jpg
# Saving 39.jpg to 39 (1).jpg
# Saving 40.jpg to 40 (1).jpg
# Saving 41.jpg to 41 (1).jpg
# Saving 42.jpg to 42 (1).jpg
# Saving 43.jpg to 43 (1).jpg
# Saving 44.jpg to 44 (1).jpg
# Saving 45.jpg to 45 (1).jpg
# Saving 46.jpg to 46 (1).jpg
# Saving 47.jpg to 47 (1).jpg
# Saving 48.jpg to 48 (1).jpg
# Saving 49.jpg to 49 (1).jpg
# Saving 50.jpg to 50 (1).jpg
# Saving 51.jpg to 51 (1).jpg
# Saving 52.jpg to 52 (1).jpg
# Saving 53.jpg to 53 (1).jpg
# Saving 54.jpg to 54 (1).jpg
# Saving 55.jpg to 55 (1).jpg
# Saving 56.jpg to 56 (1).jpg
# Saving 57.jpg to 57 (1).jpg
# Saving 58.jpg to 58 (1).jpg
# Saving 59.jpg to 59 (1).jpg
# Saving 60.jpg to 60 (1).jpg
# Saving 61.jpg to 61 (1).jpg
# Saving 62.jpg to 62 (1).jpg
# Saving 63.jpg to 63 (1).jpg
# Saving 64.jpg to 64 (1).jpg
# Saving 65.jpg to 65 (1).jpg
# Saving 66.jpg to 66 (1).jpg
# Saving 67.jpg to 67 (1).jpg
# Saving 68.jpg to 68 (1).jpg
# Saving 69.jpg to 69 (1).jpg
# Saving 70.jpg to 70 (1).jpg
# Saving 71.jpg to 71 (1).jpg
# Saving 72.jpg to 72 (1).jpg
# Saving 73.jpg to 73 (1).jpg
# Saving 74.jpg to 74 (1).jpg
# Saving 75.jpg to 75 (1).jpg
# Saving 76.jpg to 76 (1).jpg
# Saving 77.jpg to 77 (1).jpg
# Saving 78.jpg to 78 (1).jpg
# Saving 79.jpg to 79 (1).jpg
# Saving 80.jpg to 80 (1).jpg
# Saving 81.jpg to 81 (1).jpg
# Saving 82.jpg to 82 (1).jpg
# Saving 83.jpg to 83 (1).jpg
# Saving 84.jpg to 84 (1).jpg
# Saving 85.jpg to 85 (1).jpg
# Saving 86.jpg to 86 (1).jpg
# Saving 87.jpg to 87 (1).jpg
# Saving 88.jpg to 88 (1).jpg
# Saving 89.jpg to 89 (1).jpg
# Saving 90.jpg to 90 (1).jpg
# Saving 91.jpg to 91 (1).jpg
# Saving 92.jpg to 92 (1).jpg
# Saving 93.jpg to 93 (1).jpg
# Saving 94.jpg to 94 (1).jpg
# Saving 95.jpg to 95 (1).jpg
# Saving 96.jpg to 96 (1).jpg
# Saving 97.jpg to 97 (1).jpg
# Saving 98.jpg to 98 (1).jpg
# Saving 99.jpg to 99 (1).jpg
# Saving 100.jpg to 100 (1).jpg
# Saving 101.jpg to 101 (1).jpg
# Saving 102.jpg to 102 (1).jpg
# Saving 103.jpg to 103 (1).jpg
# Saving 104.jpg to 104 (1).jpg
# Saving 105.jpg to 105 (1).jpg
# Saving 106.jpg to 106 (1).jpg
# Saving 107.jpg to 107 (1).jpg
# Saving 108.jpg to 108 (1).jpg
# Saving 109.jpg to 109 (1).jpg
# Saving 110.jpg to 110 (1).jpg
# Saving 111.jpg to 111 (1).jpg
# Saving 112.jpg to 112 (1).jpg
# Saving 113.jpg to 113 (1).jpg
# Saving 114.jpg to 114 (1).jpg
# Saving 115.jpg to 115 (1).jpg
# Saving 116.jpg to 116 (1).jpg
# Saving 117.jpg to 117 (1).jpg
# Saving 118.jpg to 118 (1).jpg
# Saving 119.jpg to 119 (1).jpg
# Saving 120.jpg to 120 (1).jpg
# Saving 121.jpg to 121 (1).jpg
# Saving 122.jpg to 122 (1).jpg
# Saving 123.jpg to 123 (1).jpg
# Saving 124.jpg to 124 (1).jpg
# Saving 125.jpg to 125 (1).jpg
# Saving 126.jpg to 126 (1).jpg
# Saving 127.jpg to 127 (1).jpg
# Saving 128.jpg to 128 (1).jpg
# Saving 129.jpg to 129 (1).jpg
# Saving 130.jpg to 130 (1).jpg
# Saving 131.jpg to 131 (1).jpg
# Saving 132.jpg to 132 (1).jpg
# Saving 133.jpg to 133 (1).jpg
# Saving 134.jpg to 134 (1).jpg
# Saving 135.jpg to 135 (1).jpg
# Saving 136.jpg to 136 (1).jpg
# Saving 137.jpg to 137 (1).jpg
# Saving 138.jpg to 138 (1).jpg
# Saving 139.jpg to 139 (1).jpg
# Saving 140.jpg to 140 (1).jpg
# Saving 141.jpg to 141 (1).jpg
# Saving 142.jpg to 142 (1).jpg
# Saving 143.jpg to 143 (1).jpg
# Saving 144.jpg to 144 (1).jpg
# Saving 145.jpg to 145 (1).jpg
# Saving 146.jpg to 146 (1).jpg
# Saving 147.jpg to 147 (1).jpg
# Saving 148.jpg to 148 (1).jpg
# Saving 149.jpg to 149 (1).jpg
# Saving 150.jpg to 150 (1).jpg
# Saving 151.jpg to 151 (1).jpg
# Saving 152.jpg to 152 (1).jpg
# Saving 153.jpg to 153 (1).jpg
# Saving 154.jpg to 154 (1).jpg
# Saving 155.jpg to 155 (1).jpg
# Saving 156.jpg to 156 (1).jpg
# Saving 157.jpg to 157 (1).jpg
# Saving 158.jpg to 158 (1).jpg
# Saving 159.jpg to 159 (1).jpg
# Saving 160.jpg to 160 (1).jpg
# Saving 161.jpg to 161 (1).jpg
# Saving 162.jpg to 162 (1).jpg
# Saving 163.jpg to 163 (1).jpg
# Saving 164.jpg to 164 (1).jpg
# Saving 165.jpg to 165 (1).jpg
# Saving 166.jpg to 166 (1).jpg
# Saving 167.jpg to 167 (1).jpg
# Saving 168.jpg to 168 (1).jpg
# Saving 169.jpg to 169 (1).jpg
# Saving 170.jpg to 170 (1).jpg
# Saving 171.jpg to 171 (1).jpg
# Saving 172.jpg to 172 (1).jpg
# Saving 173.jpg to 173 (1).jpg
# Saving 174.jpg to 174 (1).jpg
# Saving 175.jpg to 175 (1).jpg
# Saving 176.jpg to 176 (1).jpg
# Saving 177.jpg to 177 (1).jpg
# Saving 178.jpg to 178 (1).jpg
# Saving 179.jpg to 179 (1).jpg
# Saving 180.jpg to 180 (1).jpg
# Saving 181.jpg to 181 (1).jpg
# Saving 182.jpg to 182 (1).jpg
# Saving 183.jpg to 183 (1).jpg
# Saving 184.jpg to 184 (1).jpg
# Saving 185.jpg to 185 (1).jpg
# Saving 186.jpg to 186 (1).jpg
# Saving 187.jpg to 187 (1).jpg
# Saving 188.jpg to 188 (1).jpg
# Saving 189.jpg to 189 (1).jpg
# Saving 190.jpg to 190 (1).jpg
# Saving 191.jpg to 191 (1).jpg
# Saving 192.jpg to 192 (1).jpg
# Saving 193.jpg to 193 (1).jpg
# Saving 194.jpg to 194 (1).jpg
# Saving 195.jpg to 195 (1).jpg
# Saving 196.jpg to 196 (1).jpg
# Saving 197.jpg to 197 (1).jpg
# Saving 198.jpg to 198 (1).jpg
# Saving 199.jpg to 199 (1).jpg
# Saving 200.jpg to 200 (1).jpg
# Saving 201.jpg to 201 (1).jpg
# Saving 202.jpg to 202 (1).jpg
# Saving 203.jpg to 203 (1).jpg
# Saving 204.jpg to 204 (1).jpg
# Saving 205.jpg to 205 (1).jpg
# Saving 206.jpg to 206 (1).jpg
# Saving 207.jpg to 207 (1).jpg
# Saving 208.jpg to 208 (1).jpg
# Saving 209.jpg to 209 (1).jpg
# Saving 210.jpg to 210 (1).jpg
# Saving 211.jpg to 211 (1).jpg
# Saving 212.jpg to 212 (1).jpg
# Saving 213.jpg to 213 (1).jpg
# Saving 214.jpg to 214 (1).jpg
# Saving 215.jpg to 215 (1).jpg
# Saving 216.jpg to 216 (1).jpg
# Saving 217.jpg to 217 (1).jpg
# Saving 218.jpg to 218 (1).jpg
# Saving 219.jpg to 219 (1).jpg
# Saving 220.jpg to 220 (1).jpg
# Saving 221.jpg to 221 (1).jpg
# Saving 222.jpg to 222 (1).jpg
# Saving 223.jpg to 223 (1).jpg
# Saving 224.jpg to 224 (1).jpg
# Saving 225.jpg to 225 (1).jpg
# Saving 226.jpg to 226 (1).jpg
# Saving 227.jpg to 227 (1).jpg
# Saving 228.jpg to 228 (1).jpg
# Saving 229.jpg to 229 (1).jpg
# Saving 230.jpg to 230 (1).jpg
# Saving 231.jpg to 231 (1).jpg
# Saving 232.jpg to 232 (1).jpg
# Saving 233.jpg to 233 (1).jpg
# Saving 234.jpg to 234 (1).jpg
# Saving 235.jpg to 235 (1).jpg
# Saving 236.jpg to 236 (1).jpg
# Saving 237.jpg to 237 (1).jpg
# Saving 238.jpg to 238 (1).jpg
# Saving 239.jpg to 239 (1).jpg
# Saving 240.jpg to 240 (1).jpg
# Saving 241.jpg to 241 (1).jpg
# Saving 242.jpg to 242 (1).jpg
# Saving 243.jpg to 243 (1).jpg
# Saving 244.jpg to 244 (1).jpg
# Saving 245.jpg to 245 (1).jpg
# Saving 246.jpg to 246 (1).jpg
# Saving 247.jpg to 247 (1).jpg
# Saving 248.jpg to 248 (1).jpg
# Saving 249.jpg to 249 (1).jpg
# Saving 250.jpg to 250 (1).jpg
# Saving 251.jpg to 251 (1).jpg
# Saving 252.jpg to 252 (1).jpg
# Saving 253.jpg to 253 (1).jpg
# Saving 254.jpg to 254 (1).jpg
# Saving 255.jpg to 255 (1).jpg
# Saving 256.jpg to 256 (1).jpg
# Saving 257.jpg to 257 (1).jpg
# Saving 258.jpg to 258 (1).jpg
# Saving 259.jpg to 259 (1).jpg
# Saving 260.jpg to 260 (1).jpg
# Saving 261.jpg to 261 (1).jpg
# Saving 262.jpg to 262 (1).jpg
# Saving 263.jpg to 263 (1).jpg
# Saving 264.jpg to 264 (1).jpg
# Saving 265.jpg to 265 (1).jpg
# Saving 266.jpg to 266 (1).jpg
# Saving 267.jpg to 267 (1).jpg
# Saving 268.jpg to 268 (1).jpg
# Saving 269.jpg to 269 (1).jpg
# Saving 270.jpg to 270 (1).jpg
# Saving 271.jpg to 271 (1).jpg
# Saving 272.jpg to 272 (1).jpg
# Saving 273.jpg to 273 (1).jpg
# Saving 274.jpg to 274 (1).jpg
# Saving 275.jpg to 275 (1).jpg
# Saving 276.jpg to 276 (1).jpg
# Saving 277.jpg to 277 (1).jpg
# Saving 278.jpg to 278 (1).jpg
# Saving 279.jpg to 279 (1).jpg
# Saving 280.jpg to 280 (1).jpg
# Saving 281.jpg to 281 (1).jpg
# Saving 282.jpg to 282 (1).jpg
# Saving 283.jpg to 283 (1).jpg
# Saving 284.jpg to 284 (1).jpg
# Saving 285.jpg to 285 (1).jpg
# Saving 286.jpg to 286 (1).jpg
# Saving 287.jpg to 287 (1).jpg
# Saving 288.jpg to 288 (1).jpg
# Saving 289.jpg to 289 (1).jpg
# Saving 290.jpg to 290 (1).jpg
# Saving 291.jpg to 291 (1).jpg
# Saving 292.jpg to 292 (1).jpg
# Saving 293.jpg to 293 (1).jpg
# Saving 294.jpg to 294 (1).jpg
# Saving 295.jpg to 295 (1).jpg
# Saving 296.jpg to 296 (1).jpg
# Saving 297.jpg to 297 (1).jpg
# Saving 298.jpg to 298 (1).jpg
# Saving 299.jpg to 299 (1).jpg
# Saving 300.jpg to 300 (1).jpg
# Saving 301.jpg to 301 (1).jpg
# Saving 302.jpg to 302 (1).jpg
# Saving 303.jpg to 303 (1).jpg
# Saving 304.jpg to 304 (1).jpg
# Saving 305.jpg to 305 (1).jpg
# Saving 306.jpg to 306 (1).jpg
# Saving 307.jpg to 307 (1).jpg
# Saving 308.jpg to 308 (1).jpg
# Saving 309.jpg to 309 (1).jpg
# Saving 310.jpg to 310 (1).jpg
# Saving 311.jpg to 311 (1).jpg
# Saving 312.jpg to 312 (1).jpg
# Saving 313.jpg to 313 (1).jpg
# Saving 314.jpg to 314 (1).jpg
# Saving 315.jpg to 315 (1).jpg
# Saving 316.jpg to 316 (1).jpg
# Saving 317.jpg to 317 (1).jpg
# Saving 318.jpg to 318 (1).jpg
# Saving 319.jpg to 319 (1).jpg
# Saving 320.jpg to 320 (1).jpg
# Saving 321.jpg to 321 (1).jpg
# Saving 322.jpg to 322 (1).jpg
# Saving 323.jpg to 323 (1).jpg
# Saving 324.jpg to 324 (1).jpg
# Saving 325.jpg to 325 (1).jpg
# Saving 326.jpg to 326 (1).jpg
# Saving 327.jpg to 327 (1).jpg
# Saving 328.jpg to 328 (1).jpg
# Saving 329.jpg to 329 (1).jpg
# Saving 330.jpg to 330 (1).jpg
# Saving 331.jpg to 331 (1).jpg
# Saving 332.jpg to 332 (1).jpg
# Saving 333.jpg to 333 (1).jpg
# Saving 334.jpg to 334 (1).jpg
# Saving 335.jpg to 335 (1).jpg
# Saving 336.jpg to 336 (1).jpg
# Saving 337.jpg to 337 (1).jpg
# Saving 338.jpg to 338 (1).jpg
# Saving 339.jpg to 339 (1).jpg
# Saving 340.jpg to 340 (1).jpg
# Saving 341.jpg to 341 (1).jpg
# Saving 342.jpg to 342 (1).jpg
# Saving 343.jpg to 343 (1).jpg
# Saving 344.jpg to 344 (1).jpg
# Saving 345.jpg to 345 (1).jpg
# Saving 346.jpg to 346 (1).jpg
# Saving 347.jpg to 347 (1).jpg
# Saving 348.jpg to 348 (1).jpg
# Saving 349.jpg to 349 (1).jpg
# Saving 350.jpg to 350 (1).jpg
# Saving 351.jpg to 351 (1).jpg
# Saving 352.jpg to 352 (1).jpg
# Saving 353.jpg to 353 (1).jpg
# Saving 354.jpg to 354 (1).jpg
# Saving 355.jpg to 355 (1).jpg
# Saving 356.jpg to 356 (1).jpg
# Saving 357.jpg to 357 (1).jpg
# Saving 358.jpg to 358 (1).jpg
# Saving 359.jpg to 359 (1).jpg
# Saving 360.jpg to 360 (1).jpg
# Saving 361.jpg to 361 (1).jpg
# Saving 362.jpg to 362 (1).jpg
# Saving 363.jpg to 363 (1).jpg
# Saving 364.jpg to 364 (1).jpg
# Saving 365.jpg to 365 (1).jpg
# Saving 366.jpg to 366 (1).jpg
# Saving 367.jpg to 367 (1).jpg
# Saving 368.jpg to 368 (1).jpg
# Saving 369.jpg to 369 (1).jpg
# Saving 370.jpg to 370 (1).jpg
# Saving 371.jpg to 371 (1).jpg
# Saving 372.jpg to 372 (1).jpg
# Saving 373.jpg to 373 (1).jpg
# Saving 374.jpg to 374 (1).jpg
# Saving 375.jpg to 375 (1).jpg
# Saving 376.jpg to 376 (1).jpg
# Saving 377.jpg to 377 (1).jpg
# Saving 378.jpg to 378 (1).jpg
# Saving 379.jpg to 379 (1).jpg
# Saving 380.jpg to 380 (1).jpg
# Saving 381.jpg to 381 (1).jpg
# Saving 382.jpg to 382 (1).jpg
# Saving 383.jpg to 383 (1).jpg
# Saving 384.jpg to 384 (1).jpg
# Saving 385.jpg to 385 (1).jpg
# Saving 386.jpg to 386 (1).jpg
# Saving 387.jpg to 387 (1).jpg
# Saving 388.jpg to 388 (1).jpg
# Saving 389.jpg to 389 (1).jpg
# Saving 390.jpg to 390 (1).jpg
# Saving 391.jpg to 391 (1).jpg
# Saving 392.jpg to 392 (1).jpg
# Saving 393.jpg to 393 (1).jpg
# Saving 394.jpg to 394 (1).jpg
# Saving 395.jpg to 395 (1).jpg
# Saving 396.jpg to 396 (1).jpg
# Saving 397.jpg to 397 (1).jpg
# Saving 398.jpg to 398 (1).jpg
# Saving 399.jpg to 399 (1).jpg
# Saving 400.jpg to 400 (1).jpg
# Saving 401.jpg to 401 (1).jpg
# Saving 402.jpg to 402 (1).jpg
# Saving 403.jpg to 403 (1).jpg
# Saving 404.jpg to 404 (1).jpg
# Saving 405.jpg to 405 (1).jpg
# Saving 406.jpg to 406 (1).jpg
# Saving 407.jpg to 407 (1).jpg
# Saving 408.jpg to 408 (1).jpg
# Saving 409.jpg to 409 (1).jpg
# Saving 410.jpg to 410 (1).jpg
# Saving 411.jpg to 411 (1).jpg
# Saving 412.jpg to 412 (1).jpg
# Saving 413.jpg to 413 (1).jpg
# Saving 414.jpg to 414 (1).jpg
# Saving 415.jpg to 415 (1).jpg
# Saving 416.jpg to 416 (1).jpg
# Saving 417.jpg to 417 (1).jpg
# Saving 418.jpg to 418 (1).jpg
# Saving 419.jpg to 419 (1).jpg
# Saving 420.jpg to 420 (1).jpg
# Saving 421.jpg to 421 (1).jpg
# Saving 422.jpg to 422 (1).jpg

# %%
im=Image.open('422.jpg')
pi = tf.keras.preprocessing.image.img_to_array(im)
pi.shape
# Out:
# (100, 100, 1)

# %%
import tensorflow.compat.v1 as tf


from keras.preprocessing.image import img_to_array
from PIL import Image
import matplotlib.pyplot as plt


L=tf.Variable(tf.ones(shape=[100, 100]), dtype=tf.float32)
L1=tf.Variable(tf.ones(shape=[100, 100]), dtype=tf.float32)

img = Image.open('1 (1).jpg')
pil_img = tf.keras.preprocessing.image.img_to_array(img)
img1 = Image.open('2 (1).jpg')

pil_img1 = tf.keras.preprocessing.image.img_to_array(img1)

L=tf.reshape(pil_img, [28, 28])
L1=tf.reshape(pil_img1, [28, 28])
t1 = L
t2 = L1
eldo=tf.concat([t1, t2], 0)

for i in range(2, 300):
    if i<10:
       S=str(i)
       
       S=S+' (1)'+'.jpg'
 
    img = Image.open(S)
    pil_img = tf.keras.preprocessing.image.img_to_array(img)
    L=tf.reshape(pil_img, [28, 28])
    t1 = L

    eldo=tf.concat([eldo, t1], 0)


eldo.shape

eldo=tf.reshape(eldo, [300, 28, 28])
eldo.shape
L=eldo[99]

L=tf.reshape(L, [28, 28, 1])


from keras import backend as K
firstimage = K.eval(L)

pil_img = tf.keras.preprocessing.image.array_to_img(firstimage)
pil_img

from keras import backend as K
eldo = K.eval(eldo)

eldo

import numpy as np

firstpart=np.zeros(250,dtype='float32')
secondpart=np.ones(250,dtype='float32')
y_train_eldo=np.concatenate((firstpart, secondpart), axis=0)
x_train_eldo=eldo

img = Image.open('301 (1).jpg')
pil_img = tf.keras.preprocessing.image.img_to_array(img)
img1 = Image.open('301 (1).jpg')

pil_img1 = tf.keras.preprocessing.image.img_to_array(img1)

L=tf.reshape(pil_img, [28, 28])
L1=tf.reshape(pil_img1, [28, 28])
t1 = L
t2 = L1
eldo_test=tf.concat([t1, t2], 0)

for i in range(300,400):
    if i<600:
       S=str(i)
       S=S+' (1)'+'.jpg'
    img = Image.open(S)
    pil_img = tf.keras.preprocessing.image.img_to_array(img)
    L=tf.reshape(pil_img, [28, 28])
    t1 = L

    eldo_test=tf.concat([eldo_test, t1], 0)

eldo_test=tf.reshape(eldo_test, [102, 28, 28])
eldo_test.shape


from keras import backend as K
eldo_test = K.eval(eldo_test)



firstpart=np.zeros(25,dtype='float32')
secondpart=np.ones(25,dtype='float32')
y_test_eldo=np.concatenate((firstpart, secondpart), axis=0)
x_test_eldo=eldo_test

x_test_eldo
# Out:
# array([[[104., 104., 104., ..., 104., 104., 104.],
#         [104., 104., 104., ..., 104., 104., 104.],
#         [104., 104., 104., ..., 104., 104., 104.],
#         ...,
#         [104., 104., 104., ..., 104., 104., 104.],
#         [104., 104., 104., ..., 104., 104., 104.],
#         [104., 104., 104., ..., 104., 104., 104.]],
#
#        [[104., 104., 104., ..., 104., 104., 104.],
#         [104., 104., 104., ..., 104., 104., 104.],
#         [104., 104., 104., ..., 104., 104., 104.],
#         ...,
#         [104., 104., 104., ..., 104., 104., 104.],
#         [104., 104., 104., ..., 104., 104., 104.],
#         [104., 104., 104., ..., 104., 104., 104.]],
#
#        [[ 93.,  93.,  93., ...,  95.,  92.,  90.],
#         [ 93.,  93.,  93., ...,  95.,  93.,  90.],
#         [ 93.,  93.,  93., ...,  95.,  95.,  91.],
#         ...,
#         [ 93.,  93.,  93., ...,  93.,  93.,  93.],
#         [ 93.,  93.,  93., ...,  93.,  93.,  93.],
#         [ 93.,  93.,  93., ...,  93.,  93.,  93.]],
#
#        ...,
#
#        [[119., 119., 119., ..., 119., 119., 119.],
#         [119., 119., 119., ..., 119., 119., 119.],
#         [119., 119., 119., ..., 119., 119., 119.],
#         ...,
#         [119., 119., 119., ..., 119., 119., 119.],
#         [119., 119., 119., ..., 119., 119., 119.],
#         [119., 119., 119., ..., 119., 119., 119.]],
#
#        [[122., 122., 122., ..., 122., 122., 122.],
#         [122., 122., 122., ..., 122., 122., 122.],
#         [122., 122., 122., ..., 122., 122., 122.],
#         ...,
#         [122., 122., 122., ..., 122., 122., 122.],
#         [122., 122., 122., ..., 122., 122., 122.],
#         [122., 122., 122., ..., 122., 122., 122.]],
#
#        [[156., 156., 156., ..., 156., 156., 156.],
#         [156., 156., 156., ..., 156., 156., 156.],
#         [156., 156., 156., ..., 156., 156., 156.],
#         ...,
#         [156., 156., 156., ..., 156., 156., 156.],
#         [156., 156., 156., ..., 156., 156., 156.],
#         [156., 156., 156., ..., 156., 156., 156.]]], dtype=float32)

# %%
eldo_test.shape
# Out:
# TensorShape([5656, 28])

# %%
# load dataset
train_images=x_train_eldo
test_images=x_test_eldo
# split dataset
train_images = train_images.reshape(train_images.shape[0], 28, 28, 1).astype(
    "float32"
) / 255.0
test_images = test_images.reshape(test_images.shape[0], 28, 28, 1).astype("float32") / 255.0

# batch datasets
train_dataset = (
    tf.data.Dataset.from_tensor_slices(train_images)
    .shuffle(TRAIN_BUF)
    .batch(BATCH_SIZE)
)
test_dataset = (
    tf.data.Dataset.from_tensor_slices(test_images)
    .shuffle(TEST_BUF)
    .batch(BATCH_SIZE)
)

# %% [markdown]
# ### Define the network as tf.keras.model object

# %%
class GAN(tf.keras.Model):
    """ a basic GAN class 
    Extends:
        tf.keras.Model
    """

    def __init__(self, **kwargs):
        super(GAN, self).__init__()
        self.__dict__.update(kwargs)

        self.gen = tf.keras.Sequential(self.gen)
        self.disc = tf.keras.Sequential(self.disc)

    def generate(self, z):
        return self.gen(z)

    def discriminate(self, x):
        return self.disc(x)

    def compute_loss(self, x):
        """ passes through the network and computes loss
        """
        # generating noise from a uniform distribution
        z_samp = tf.random.normal([x.shape[0], 1, 1, self.n_Z])

        # run noise through generator
        x_gen = self.generate(z_samp)
        # discriminate x and x_gen
        logits_x = self.discriminate(x)
        logits_x_gen = self.discriminate(x_gen)
        ### losses
        # losses of real with label "1"
        disc_real_loss = gan_loss(logits=logits_x, is_real=True)
        # losses of fake with label "0"
        disc_fake_loss = gan_loss(logits=logits_x_gen, is_real=False)
        disc_loss = disc_fake_loss + disc_real_loss

        # losses of fake with label "1"
        gen_loss = gan_loss(logits=logits_x_gen, is_real=True)

        return disc_loss, gen_loss

    def compute_gradients(self, x):
        """ passes through the network and computes loss
        """
        ### pass through network
        with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
            disc_loss, gen_loss = self.compute_loss(x)

        # compute gradients
        gen_gradients = gen_tape.gradient(gen_loss, self.gen.trainable_variables)
        disc_gradients = disc_tape.gradient(disc_loss, self.disc.trainable_variables)

        return gen_gradients, disc_gradients

    def apply_gradients(self, gen_gradients, disc_gradients):

        self.gen_optimizer.apply_gradients(
            zip(gen_gradients, self.gen.trainable_variables)
        )
        self.disc_optimizer.apply_gradients(
            zip(disc_gradients, self.disc.trainable_variables)
        )
    @tf.function
    def train(self, train_x):
        gen_gradients, disc_gradients = self.compute_gradients(train_x)
        self.apply_gradients(gen_gradients, disc_gradients)
        
        
def gan_loss(logits, is_real=True):
    """Computes standard gan loss between logits and labels
    """
    if is_real:
        labels = tf.ones_like(logits)
    else:
        labels = tf.zeros_like(logits)

    return tf.compat.v1.losses.sigmoid_cross_entropy(
        multi_class_labels=labels, logits=logits
    )

# %% [markdown]
# ### Define the network architecture

# %%
N_Z = 16
generator = [
    tf.keras.layers.Dense(units=7 * 7 * 64, activation="relu"),
    tf.keras.layers.Reshape(target_shape=(7, 7, 64)),
    tf.keras.layers.Conv2DTranspose(
        filters=64, kernel_size=3, strides=(2, 2), padding="SAME", activation="relu"
    ),
    tf.keras.layers.Conv2DTranspose(
        filters=32, kernel_size=3, strides=(2, 2), padding="SAME", activation="relu"
    ),
    tf.keras.layers.Conv2DTranspose(
        filters=1, kernel_size=3, strides=(1, 1), padding="SAME", activation="sigmoid"
    ),
]

discriminator = [
    tf.keras.layers.InputLayer(input_shape=DIMS),
    tf.keras.layers.Conv2D(
        filters=32, kernel_size=3, strides=(2, 2), activation="relu"
    ),
    tf.keras.layers.Conv2D(
        filters=64, kernel_size=3, strides=(2, 2), activation="relu"
    ),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(units=1, activation=None),
]

# %% [markdown]
# ### Create Model

# %%
# optimizers
gen_optimizer = tf.keras.optimizers.Adam(0.001, beta_1=0.5)
disc_optimizer = tf.keras.optimizers.RMSprop(0.001)# train the model
# model
model = GAN(
    gen = generator,
    disc = discriminator,
    gen_optimizer = gen_optimizer,
    disc_optimizer = disc_optimizer,
    n_Z = N_Z
)

# %% [markdown]
# ### Train the model

# %%
# exampled data for plotting results
def plot_reconstruction(model, nex=8, zm=2):
    samples = model.generate(tf.random.normal(shape=(BATCH_SIZE, N_Z)))
    fig, axs = plt.subplots(ncols=nex, nrows=1, figsize=(zm * nex, zm))
    for axi in range(nex):
        axs[axi].matshow(
                    samples.numpy()[axi].squeeze(), cmap=plt.cm.Greys, vmin=0, vmax=1
                )
        axs[axi].axis('off')
    plt.show()

# %%
# a pandas dataframe to save the loss information to
losses = pd.DataFrame(columns = ['disc_loss', 'gen_loss'])

# %%
n_epochs = 500
for epoch in range(n_epochs):
    # train
    for batch, train_x in tqdm(
        zip(range(N_TRAIN_BATCHES), train_dataset), total=N_TRAIN_BATCHES
    ):
        model.train(train_x)
    # test on holdout
    loss = []
    for batch, test_x in tqdm(
        zip(range(N_TEST_BATCHES), test_dataset), total=N_TEST_BATCHES
    ):
        loss.append(model.compute_loss(train_x))
    losses.loc[len(losses)] = np.mean(loss, axis=0)
    # plot results
    display.clear_output()
    print(
        "Epoch: {} | disc_loss: {} | gen_loss: {}".format(
            epoch, losses.disc_loss.values[-1], losses.gen_loss.values[-1]
        )
    )
    plot_reconstruction(model)
# Out:
# Epoch: 35 | disc_loss: 1.4551341533660889 | gen_loss: 0.45986002683639526
